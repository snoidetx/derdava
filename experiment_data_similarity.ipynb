# %% [markdown]
# # Measure of Contribution to Model Performance and Deletion Robustness
#
# ## Data Similarity
#
# How does DeRDaVa view data sources with similar data? Sample experiments are given below:

# %% [markdown]
# ### Synthetic Dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from matplotlib.collections import PatchCollection
from matplotlib.patches import Polygon
from sklearn.datasets import make_blobs

centers = [(-5, 10), (5, 10),
           (5 * 1.67 + 2.5, -5 + 2.5 * 1.67), (5 * 1.67 - 2.5, -5 - 2.5 * 1.67), 
           (-5 * 1.67 + 2.5, -5 - 2.5 * 1.67), (-5 * 1.67 - 2.5, -5 + 2.5 * 1.67)]
n_samples_per_cluster = 100

X_0 = X_1 = np.ndarray((0, 2), dtype='float')
y_0 = y_1 = np.array([])
for i in range(3):
    X_temp_0, y_temp_0 = make_blobs(n_samples=n_samples_per_cluster, centers=centers[2 * i: 2 * i + 1], shuffle=False)
    X_0 = np.concatenate((X_0, X_temp_0))
    y_0 = np.concatenate((y_0, np.full(n_samples_per_cluster, 0)))
    X_temp_1, y_temp_1 = make_blobs(n_samples=n_samples_per_cluster, centers=centers[2 * i + 1: 2 * i + 2], shuffle=False)
    X_1 = np.concatenate((X_1, X_temp_1))
    y_1 = np.concatenate((y_1, np.full(n_samples_per_cluster, 1)))
    if i == 0:
        X_red = np.concatenate((X_temp_0, X_temp_1))
        y_red = np.concatenate((np.full(n_samples_per_cluster, 0), np.full(n_samples_per_cluster, 1)))
    elif i == 1:
        X_yellow = np.concatenate((X_temp_0, X_temp_1))
        y_yellow = np.concatenate((np.full(n_samples_per_cluster, 0), np.full(n_samples_per_cluster, 1)))
    else:
        X_blue = np.concatenate((X_temp_0, X_temp_1))
        y_blue = np.concatenate((np.full(n_samples_per_cluster, 0), np.full(n_samples_per_cluster, 1)))

fig, ax = plt.subplots()

region_red = Polygon(np.array([[0, 0], [-25, 15], [25, 15]]), closed=True)
region_yellow = Polygon(np.array([[0, 0], [-25, 15], [0, -100]]), closed=True)
region_blue = Polygon(np.array([[0, 0], [25, 15], [0, -100]]), closed=True)
patches = [region_red, region_yellow, region_blue]
p = PatchCollection(patches, alpha=0.15)
p.set(facecolor=['red', 'yellow', 'blue'])
ax.add_collection(p)

ax.scatter(X_0[:, 0], X_0[:, 1], marker='.', label='Class 0')
ax.scatter(X_1[:, 0], X_1[:, 1], marker='|', label='Class 1')

ax.set_xlabel(r'Feature $x_1$', fontsize=30)
ax.set_ylabel(r'Feature $x_2$', fontsize=30)
ax.set_xlim(left=-15.5, right=15.5)
ax.set_ylim(bottom=-14, top=14)
ax.legend(facecolor='white', framealpha=0.7, fontsize='xx-large', loc='center')
ax.tick_params(axis='both', labelsize='xx-large')

plt.show()
PATH_TO_IMAGES = "./images/data_similarity/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "synthetic_dataset_visualization.png"), dpi=300, bbox_inches='tight')

# %%
from sklearn.model_selection import train_test_split

X_red_train, X_red_test, y_red_train, y_red_test = train_test_split(X_red, y_red, test_size=0.3, shuffle=True)
X_red_train, X_redd_train, y_red_train, y_redd_train = train_test_split(X_red_train, y_red_train, test_size=0.5, shuffle=True)
X_yellow_train, X_yellow_test, y_yellow_train, y_yellow_test = train_test_split(X_yellow, y_yellow, test_size=0.3, shuffle=True)
X_blue_train, X_blue_test, y_blue_train, y_blue_test = train_test_split(X_blue, y_blue, test_size=0.3, shuffle=True)
X_test = np.concatenate((X_red_test, X_yellow_test, X_blue_test))
y_test = np.concatenate((y_red_test, y_yellow_test, y_blue_test))
RED = (X_red_train, y_red_train)
REDD = (X_redd_train, y_redd_train)
YELLOW = (X_yellow_train, y_yellow_train)
BLUE = (X_blue_train, y_blue_train)

# %%
from derdava.data_valuation import ValuableModel
from derdava.model_utility import IClassificationModel, model_knn

data_sources = {0: RED, 1: REDD, 2: YELLOW, 3: BLUE}
model_utility_function = IClassificationModel(model_knn, data_sources, X_test, y_test)

valuable_model = ValuableModel((0, 1, 2, 3), model_utility_function)

# %%
from derdava.coalition_probability import IndependentCoalitionProbability

x = [[] for i in range(6)]
y = [[] for i in range(6)]

for i in range(4): # 100%, 67%, 33%, 0%
    x[i] = [1 - 0.05 * j for j in range(21)]
    for j in range(21): # 100%, 95%, ..., 5%, 0%
        coalition_probability = IndependentCoalitionProbability({0: 1 - 0.05 * j, 1: 1 - 1/3 * i, 
                                                                 2: 1 - 1/3 * i, 3: 1 - 1/3 * i})
        y[i].append(valuable_model.valuate(data_valuation_function='012-mcmc robust banzhaf', 
                                           coalition_probability=coalition_probability, tolerance=1.0005)[0])
# Out:
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9945466883852736
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9962335102054991
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0026468609819903
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0004712018574828
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0008384295441937
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0007015425656491
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0003478115924147
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0004489045536582
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0004272245975694
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.0003846108716237
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0005652016535689
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0005405838588661
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.0008417325033152
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 1.0006248686130494
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7500 - Average convergence rate = 1.0008978534154793
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 8000 - Average convergence rate = 1.0006277464088174
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8500 - Average convergence rate = 1.0002438775426612
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 9000 - Average convergence rate = 1.0005104038180814
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9500 - Average convergence rate = 1.0009461245526996
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 10000 - Average convergence rate = 1.0003654270950195
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9932142808241086
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9959826009629644
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9995432624804141
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9990201312332514
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0004799176798145
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0004300022629795
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0002073604094612
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0003682341499989
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9998929040034903
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9996604045292818
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9960907678413646
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0018152929736739
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0025293487270512
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0007270078050503
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0000536392396626
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.000846518929635
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0001377222233825
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.00048752298099
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0008707503814207
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0001375388665916
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9997713907091961
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0074974551960092
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0010549244717586
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0012833232483547
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0007324465800438
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9992934780009888
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9995318051567447
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9993968135871424
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9998269910591961
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0000493055896094
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9996730945443467
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9998844102393982
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9946490050156587
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0002123506619252
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.000019374639737
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0017816717296928
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0005891397653
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0001115957524482
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9976688308381768
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9989471507492462
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.002230446851298
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.000167975299144
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9999276496317511
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9989245657839422
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9992453239909802
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.999571411680019
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9994106555275373
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9995517040285483
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0005810352323823
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9997389282782128
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9933942713102565
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9995977834126413
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9987310448452474
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0009395978516142
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0006120462333936
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.999600288653612
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0002221902798354
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.000370454933678
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9995939916777387
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9997962806279387
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9996156674131422
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0016286785534376
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.006355522094999
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.003436795811731
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0046228990466046
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0012012824734495
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0005205016132221
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0002699454417456
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0007271086580851
# ---------> Number of values that have not converged: 2
# ...
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0005007410620745
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.999467728631592
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.999804272779157
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9996650368419608
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 4

# %%
banzhaf_score = valuable_model.valuate(data_valuation_function='banzhaf')[0]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(x[0], [banzhaf_score] * 21, linestyle='dashed', color='gray', label='Banzhaf')
for i in range(4):
    ax.plot(x[i], y[i], color='C' + str(i), label=f'{round((1 - 1/3 * i)*100)}% stay')
    
ax.set_xlabel(r'Staying prob of $\mathtt{RED}$', fontsize=30)
ax.set_ylabel('Valuation score', fontsize=30)
ax.legend(facecolor='white', framealpha=1, fontsize='xx-large', loc='upper right')
ax.tick_params(axis='both', labelsize='xx-large')
plt.gca().invert_xaxis()
PATH_TO_IMAGES = "./images/data_similarity/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "synthetic_dataset_result.png"), dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Actual Dataset

# %%
from sklearn.model_selection import train_test_split
from derdava.dataset import load_dataset
from derdava.data_source import generate_random_data_sources

X, y = load_dataset('phoneme')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
data_sources = generate_random_data_sources(X_train, y_train)

data_sources[5] = (data_sources[0][0].copy(), data_sources[0][1].copy()) # 5 is a duplicate of 0

from urdava.data_valuation import ValuableModel
from urdava.model_utility import IClassificationModel, model_logistic_regression

model_utility_function = IClassificationModel(model_logistic_regression, data_sources, X_test, y_test)

valuable_model = ValuableModel(tuple([i for i in range(6)]), model_utility_function)

from urdava.coalition_probability import IndependentCoalitionProbability

x = [[] for i in range(4)]
y = [[] for i in range(4)]

for i in range(4): # 100%, 67%, 33%, 0%:
    x[i] = [1 - 0.05 * j for j in range(21)]
    for j in range(21): # 100%, 90%, ..., 10%, 0%
        coalition_probability = IndependentCoalitionProbability({0: 1 - 0.05 * j, 1: 1 - 1/3 * i, 
                                                                 2: 1 - 1/3 * i, 3: 1 - 1/3 * i,
                                                                 4: 1 - 1/3 * i, 5: 1 - 1/3 * i}) 
        to_be_appended = valuable_model.valuate(data_valuation_function='012-mcmc robust shapley', 
                                                coalition_probability=coalition_probability, tolerance=1.0005)[0]
        while to_be_appended < 0.001 and j != 20:
            to_be_appended = valuable_model.valuate(data_valuation_function='012-mcmc robust shapley', 
                                                coalition_probability=coalition_probability, tolerance=1.0005)[0]
        y[i].append(to_be_appended)
        
shapley_score = valuable_model.valuate(data_valuation_function='shapley')[0]
# Out:
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0023195213230671
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9981225815637598
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9987036416716735
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9988744319336919
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.999685763829596
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.99913829625537
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9994695512064441
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9993580137322627
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9990902436563222
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9991526903976361
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.999539649907433
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9998971647401348
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9998408642818092
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9997883957389484
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9995021896662907
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9999206722555699
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.999740581545888
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.9997213051426587
# ---------> Number of values that have not converged: 3
# 0 0
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.996911329590036
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9987095973885056
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0000035051108955
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0006022480654544
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9998075200067538
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0003886073417922
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0012171634884728
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.001094570387801
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0007894035980054
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.000461349662676
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0000097390685958
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.000019630259201
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.0000077259505125
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9998844672092887
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7500 - Average convergence rate = 1.000081224557501
# ---------> Number of values that have not converged: 1
# 0 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0017736525919663
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0015166361838708
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9993153244431167
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0006971337977688
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9992176500610852
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9992945492041061
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.999991333096436
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0000975128158711
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9996097630099787
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9997922060023239
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0004310309415054
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9996579145763347
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.0001537226474158
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 1.000101238919055
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9999512153973086
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8000 - Average convergence rate = 1.000258940589578
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8500 - Average convergence rate = 1.0000230564174069
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.999712812098839
# ---------> Number of values that have not converged: 1
# 0 2
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0256547385141639
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0091963647385331
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.005731910700913
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0015473906062213
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0015256606344385
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0005885616257724
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0002303189098296
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9995221092862955
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9995042449154093
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9998850085097363
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9993589581064614
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9993995399983905
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9995038622873893
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9994365480681808
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9996343097959843
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9993790370374823
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.9995672920679893
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.9996208278447719
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 9500 - Average convergence rate = 0.9997441653423825
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 10000 - Average convergence rate = 0.9994656909060123
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 10500 - Average convergence rate = 0.9997364479874742
# ---------> Number of values that have not converged: 1
# 0 3
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9978736305323633
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9986408469267496
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9981194322407833
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9992762727434824
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9990948338513744
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9991699100998859
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.999477136563562
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9990927329584807
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9997679826495874
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.99982012339699
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9993449237846282
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9996851869251994
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9998741853299511
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9998202755599074
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9997922830046856
# ---------> Number of values that have not converged: 2
# 0 4
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0025652255472568
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9976526195074706
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9976914116487187
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9986265621061513
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9986794875430783
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9998329031491147
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9998213855952455
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.99971964996937
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0000638479446178
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9999930851213428
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0000084633698925
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0001385898189297
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9999944087203119
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9999242589471957
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9999597871901419
# ---------> Number of values that have not converged: 2
# 0 5
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9965299529820584
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9990450480043503
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9993586513309327
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9998369079306028
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9994251026794031
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9995082758994785
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9990961947354494
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.999349841355537
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.999615655334878
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9999843863734551
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.999878640991605
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9996477116214741
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9998929847182297
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9997125089139768
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7500 - Average convergence rate = 1.0000437848179613
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9997759262289426
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.9998188010738964
# ---------> Number of values that have not converged: 2
# 0 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9999736481461997
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0011774487291518
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0019715481894005
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999729136346612
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0006769629687737
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9999696566783695
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9999282143464209
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9997026947558664
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9994322881246354
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.0001358234312867
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9997298341853851
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0000327546991088
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.999693627545827
# ---------> Number of values that have not converged: 2
# 0 7
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9978344963448603
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9988693109385957
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9992028960074558
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9989804001755607
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0000710451342505
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9998228986249874
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9998684087388598
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.999809013109137
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.999890907340817
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.0000688839516576
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9999752171693127
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0003497879623249
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.000148416346163
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9999462567329918
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7500 - Average convergence rate = 1.0002221978412693
# ---------> Number of values that have not converged: 1
# 0 8
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9994374229164538
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9979478067261817
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9990687614705106
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9983855439657412
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9980413124578554
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9995876545253889
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9993491417439491
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9994929095717348
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0001134253341277
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9998155033585009
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9999820590762738
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9998776729227808
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9998154223032024
# ---------> Number of values that have not converged: 4
# 0 9
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0097272648867552
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9982818999236205
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9983892711202889
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9991824758134501
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9991863926354854
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9996189283262815
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9998593683647883
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0003320239496458
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0002783674371303
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9997353760722493
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9999892528878983
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0004193227878249
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.0002616933121062
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7000 - Average convergence rate = 1.0003947297617615
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7500 - Average convergence rate = 1.0001082017887033
# ---------> Number of values that have not converged: 1
# 0 10
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9995760284582803
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0000563894073606
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9994596154623739
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.998466412582672
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9982919478755955
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9994907065388782
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9996515149965276
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9994598741137538
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9995223508602015
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9996582864229272
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.999730937562413
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0000911986883552
# ---------> Number of values that have not converged: 1
# 0 11
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0086175574737184
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0007841761558742
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0012381906931018
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.000497728644701
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9993619603791123
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.001022883773122
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0009924680599256
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0010346187197763
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9998698010233485
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.0001494657545342
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9997777126366644
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0001104010207167
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9995759820664606
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9993891828835205
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9997677638456589
# ---------> Number of values that have not converged: 2
# 0 12
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0002682443344626
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.000171655516776
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9997620445581307
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0010395963723675
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0004680279090314
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9996633591134102
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.000573546852293
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0002377983622865
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9998612457694479
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9997767551404997
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9996147868721829
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.999893009079087
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9997847381772642
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9998479064489558
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9998373660463629
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 8000 - Average convergence rate = 1.000177666846292
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.9999337056158689
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.9999016429604302
# ---------> Number of values that have not converged: 2
# 0 13
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9986747758721517
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9992108476516606
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0024516438485098
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.001945224885249
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0021876241076815
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0003047479592868
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0011842655076661
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0002424793068116
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0011417645067466
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.001058498616178
# ---------> Number of values that have not converged: 5
# 0 14
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.000734657731187
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0037896146223788
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.002071667725222
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0015260859705444
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0001809501960588
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0005311327566269
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9999982283652408
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9999327937544785
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9999207939237923
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9995094864272218
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9996832978821278
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9996491736279646
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.0001062982724367
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9995773419177238
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9997929618080015
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9994764388785256
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.9997781899230049
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.9994663383850161
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 9500 - Average convergence rate = 0.9998764739663796
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 10000 - Average convergence rate = 0.999710690134814
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 10500 - Average convergence rate = 0.9997206234643902
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 11000 - Average convergence rate = 0.9998078934840656
# ---------> Number of values that have not converged: 3
# 0 15
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.003338932552367
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.001834085376109
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.000844263391108
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0007872404145657
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.001538099466221
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9998824369513829
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0003822349958238
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9999604480238385
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0001236603949646
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.0000129376199982
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.999765171236506
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.000558011701851
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.0002381339732063
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 7000 - Average convergence rate = 1.000256611767277
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9999561018328036
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9997769851554601
# ---------> Number of values that have not converged: 3
# 0 16
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9979643254800207
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9997565008827641
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0009975339485393
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0011159341210378
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9999408419118608
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0013078382194516
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.00096400988326
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0003248407249667
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9996610820640361
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9998619880343892
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9997777357867276
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9998463972529267
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9997702172772892
# ---------> Number of values that have not converged: 2
# 0 17
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0067602513975953
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0016198515121904
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0012927312971296
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999465776412123
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0009534857366313
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0010569927895718
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0006765293322135
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.0006154393248712
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0014203003155409
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.0012339590249586
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0003450480580935
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = 1.0003055402793801
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6500 - Average convergence rate = 1.000726408989775
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7000 - Average convergence rate = 1.0004688386732978
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7500 - Average convergence rate = 1.0003120374708516
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 8000 - Average convergence rate = 1.0002859044011954
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 8500 - Average convergence rate = 1.0000148094410197
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 9000 - Average convergence rate = 1.0002955581416175
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9500 - Average convergence rate = 1.0003944446837592
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 10000 - Average convergence rate = 1.000522744784574
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 10500 - Average convergence rate = 1.0003856395455362
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 11000 - Average convergence rate = 1.0004225892612686
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 11500 - Average convergence rate = 1.0004341083972044
# ---------> Number of values that have not converged: 3
# 0 18
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9993352526103405
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9994609727252488
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0012383586914924
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9998697055998772
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.000571870259919
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9995662481031284
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.99974792469769
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4000 - Average convergence rate = 1.000057181303972
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 1.0004745182354413
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5000 - Average convergence rate = 1.000442438864081
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9997778925931945
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9998284294603788
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9996595785533063
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9995574039536962
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9998653084318011
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.999816511320106
# ---------> Number of values that have not converged: 2
# 0 19
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# /home/tianxiao/URDaVa/urdava/urdava/sampling.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   statistics[i] = (((chain_len - 1) * mean_within_chain_variance + between_chain_variance) /
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# 0 20
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0002782058854487
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9994516412717837
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9968527074795969
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9986981143225703
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9997876028521858
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0000216582206363
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0006951561592239
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.99993998847494
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9998047397826678
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9994708215016127
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.0007396724888296
# ---------> Number of values that have not converged: 4
# ...
# ====> Monte-Carlo Round 12000 - Average convergence rate = 1.000450772281688
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 12500 - Average convergence rate = 1.0003222281004083
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 13000 - Average convergence rate = 1.0003568980012503
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 13500 - Average convergence rate = 1.0001195045091418
# ---------> Number of values that have not converged: 1
# 2 17
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9974970398381563
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9962080611872907
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9983188098304924
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9981576526114605
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9993030615673218
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9991270387443766
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9999265667821639
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9994257033349606
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9996166843904325
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.999736038268991
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = 1.000115784948556
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9999228942253177
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9996135874147066
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = 1.000075251050765
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9996508410363952
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9999461992028378
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.9996486963220814
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.9995481059173202
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9500 - Average convergence rate = 0.9994451891003554
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 10000 - Average convergence rate = 0.999852936684956
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 10500 - Average convergence rate = 0.9996081604881057
# ---------> Number of values that have not converged: 1
# 2 18
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0008577079054655
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9989640013658141
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9982233778541203
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9977782942982393
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9991403972385928
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = 0.9990661029223872
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = 0.9988912360037773
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 4000 - Average convergence rate = 0.9992789678221272
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = 0.9999247397951719
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 5000 - Average convergence rate = 0.9994502610053818
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 5500 - Average convergence rate = 0.9996719208097223
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 6000 - Average convergence rate = 0.9997122786591496
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6500 - Average convergence rate = 0.9994435414680135
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 7000 - Average convergence rate = 0.9995129355145362
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 7500 - Average convergence rate = 0.9993890747763352
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 8000 - Average convergence rate = 0.9997033064065279
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 8500 - Average convergence rate = 0.9994161666636373
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 9000 - Average convergence rate = 0.99951851372425
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 9500 - Average convergence rate = 0.99981234930153
# ---------> Number of values that have not converged: 2
# 2 19
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 5000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 5500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 6000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 6500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 7000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 7500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 8000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 2
# 2 20
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 0
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 1
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 2
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 3
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 4
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 5
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 1500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 4000 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 7
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 8
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 9
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 10
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 11
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 12
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 13
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 14
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 500 - Average convergence rate = nan
# ---------> Number of values that have not converged: 1
# 3 15
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 16
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 17
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 18
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 19
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 6
# 3 20

# %%
import matplotlib.pyplot as plt
import os

fig, ax = plt.subplots()
ax.plot(x[0], [shapley_score] * 21, linestyle='dashed', color='gray', label='Shapley')
for i in range(4):
    ax.plot(x[i], y[i], color='C' + str(i), label=f'{round((1 - 1/3 * i)*100)}% stay')
    
ax.set_xlabel(r'Staying prob of $\mathtt{DUP}$', fontsize=30)
ax.set_ylabel('Valuation score', fontsize=30)
ax.legend(facecolor='white', framealpha=1, fontsize='xx-large', loc='upper right')
ax.tick_params(axis='both', labelsize='xx-large')
plt.gca().invert_xaxis()
PATH_TO_IMAGES = "./images/data_similarity/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "ds_5_phoneme_lr_shapley"), dpi=300, bbox_inches='tight')
