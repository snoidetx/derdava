# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from statistics import mean, stdev
from urdava.coalition_probability import IndependentCoalitionProbability
from urdava.data_source import generate_random_data_sources, add_classification_noise
from urdava.data_valuation import ValuableModel
from urdava.dataset import load_dataset
from urdava.model_utility import IClassificationModel, model_logistic_regression

# Add logs
import logging
import sys
logger = logging.getLogger()
formatter = logging.Formatter('%(asctime)s - %(lineno)s - %(levelname)s - %(message)s')
logger.setLevel(logging.DEBUG)

fhandler = logging.FileHandler(filename='main4.log', mode='w')
fhandler.setFormatter(formatter)
fhandler.setLevel(logging.INFO)
logger.addHandler(fhandler)

consoleHandler = logging.StreamHandler(sys.stdout)
consoleHandler.setFormatter(formatter)
consoleHandler.setLevel(logging.DEBUG)
logger.addHandler(consoleHandler)

logger.info("Program has started.")

X, y = load_dataset('phoneme')
one_indices = np.random.choice(np.asarray(y == 1).nonzero()[0], size=int(len(y[y == 2]) * 1.5), replace=False)
two_indices = np.asarray(y == 2).nonzero()[0]
indices = np.concatenate([one_indices, two_indices])
X = X[indices]
y = y[indices]
y = add_classification_noise(y, noise_level=0.1)
X, y = shuffle(X, y)
X, X_test, y, y_test = train_test_split(X, y, test_size=0.2)

NUM_OF_DATA_SOURCES = 100
support_set = tuple(range(NUM_OF_DATA_SOURCES))
staying_probabilities = {i:0.5 for i in range(NUM_OF_DATA_SOURCES)}
coalition_probability = IndependentCoalitionProbability(staying_probabilities)
model = model_logistic_regression

random_orders = []
loo_orders = []
shapley_orders = []
derdava_shapley_orders = []

for N in range(50):
    logger.info(f"====> Iteration {N} =====")
    indices = np.random.choice(len(X), size=NUM_OF_DATA_SOURCES, replace=False)
    X_train = X[indices]
    y_train = y[indices]
    data_sources = {i: (X_train[i:i+1], y_train[i:i+1]) for i in range(NUM_OF_DATA_SOURCES)}
    model_utility_function = IClassificationModel(model, data_sources, X_test, y_test)
    valuable_model = ValuableModel(support_set, model_utility_function)
    random_order = np.arange(NUM_OF_DATA_SOURCES)
    np.random.shuffle(random_order)
    random_orders.append(indices[random_order])
    
    logger.info("---------> Random done.")
    
    loo_values = valuable_model.valuate(data_valuation_function='loo')
    loo_order = sorted(support_set, key=lambda x: loo_values[x], reverse=True)
    loo_orders.append(indices[loo_order])
    
    logger.info("---------> LOO done.")
    
    shapley_values = valuable_model.valuate(data_valuation_function='monte-carlo shapley',
                                            tolerance=1.005)
    shapley_order = sorted(support_set, key=lambda x: shapley_values[x], reverse=True)
    shapley_orders.append(indices[shapley_order])
    
    logger.info("---------> Shapley done.")
    
    derdava_shapley_values = valuable_model.valuate(data_valuation_function='012-mcmc robust shapley',
                                                    coalition_probability=coalition_probability,
                                                    tolerance=1.005)
    derdava_shapley_order = sorted(support_set, key=lambda x: derdava_shapley_values[x], reverse=True)
    derdava_shapley_orders.append(indices[derdava_shapley_order])
    
    logger.info("---------> DeRDaVa done.")
    
logger.info("Random orders: " + str(random_orders))
logger.info("LOO orders: " + str(loo_orders))
logger.info("Shapley orders: " + str(shapley_orders))
logger.info("DeRDaVa Shapley orders: " + str(derdava_shapley_orders))
# Out:
# 2023-05-16 14:03:43,602 - 29 - INFO - Program has started.
# 2023-05-16 14:03:43,602 - 29 - INFO - Program has started.
# 2023-05-16 14:03:43,602 - 29 - INFO - Program has started.
# 2023-05-16 14:03:43,602 - 29 - INFO - Program has started.
# 2023-05-16 14:03:43,602 - 29 - INFO - Program has started.
# 2023-05-16 14:03:43,625 - 53 - INFO - ====> Iteration 0 =====
# 2023-05-16 14:03:43,625 - 53 - INFO - ====> Iteration 0 =====
# 2023-05-16 14:03:43,625 - 53 - INFO - ====> Iteration 0 =====
# 2023-05-16 14:03:43,625 - 53 - INFO - ====> Iteration 0 =====
# 2023-05-16 14:03:43,625 - 53 - INFO - ====> Iteration 0 =====
# 2023-05-16 14:03:43,747 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:03:43,747 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:03:43,747 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:03:43,747 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:03:43,747 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:03:43,965 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:03:43,965 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:03:43,965 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:03:43,965 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:03:43,965 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9982031842987031
# ---------> Number of values that have not converged: 50
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9991201504813261
# ---------> Number of values that have not converged: 24
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.99954421739141
# ---------> Number of values that have not converged: 8
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0000599142695699
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9999936845398261
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.000365374327927
# ---------> Number of values that have not converged: 2
# 2023-05-16 14:13:44,067 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:13:44,067 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:13:44,067 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:13:44,067 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:13:44,067 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9993411812113099
# ---------> Number of values that have not converged: 25
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9988237319405913
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9998444586377943
# ---------> Number of values that have not converged: 2
# 2023-05-16 14:20:24,883 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:20:24,883 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:20:24,883 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:20:24,883 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:20:24,883 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:20:24,889 - 53 - INFO - ====> Iteration 1 =====
# 2023-05-16 14:20:24,889 - 53 - INFO - ====> Iteration 1 =====
# 2023-05-16 14:20:24,889 - 53 - INFO - ====> Iteration 1 =====
# 2023-05-16 14:20:24,889 - 53 - INFO - ====> Iteration 1 =====
# 2023-05-16 14:20:24,889 - 53 - INFO - ====> Iteration 1 =====
# 2023-05-16 14:20:25,005 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:20:25,005 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:20:25,005 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:20:25,005 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:20:25,005 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:20:25,214 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:20:25,214 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:20:25,214 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:20:25,214 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:20:25,214 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9999469829256139
# ---------> Number of values that have not converged: 50
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9993283981684996
# ---------> Number of values that have not converged: 21
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9997464959130337
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999430126877109
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9998656689677994
# ---------> Number of values that have not converged: 1
# 2023-05-16 14:28:57,726 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:28:57,726 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:28:57,726 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:28:57,726 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:28:57,726 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0017679565890054
# ---------> Number of values that have not converged: 15
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0006432148615476
# ---------> Number of values that have not converged: 7
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9997405489269964
# ---------> Number of values that have not converged: 1
# 2023-05-16 14:34:52,745 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:34:52,745 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:34:52,745 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:34:52,745 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:34:52,745 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:34:52,750 - 53 - INFO - ====> Iteration 2 =====
# 2023-05-16 14:34:52,750 - 53 - INFO - ====> Iteration 2 =====
# 2023-05-16 14:34:52,750 - 53 - INFO - ====> Iteration 2 =====
# 2023-05-16 14:34:52,750 - 53 - INFO - ====> Iteration 2 =====
# 2023-05-16 14:34:52,750 - 53 - INFO - ====> Iteration 2 =====
# 2023-05-16 14:34:52,865 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:34:52,865 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:34:52,865 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:34:52,865 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:34:52,865 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:34:53,093 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:34:53,093 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:34:53,093 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:34:53,093 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:34:53,093 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.000150027676932
# ---------> Number of values that have not converged: 55
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0009043046259338
# ---------> Number of values that have not converged: 30
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0003033506761796
# ---------> Number of values that have not converged: 11
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.000090368544871
# ---------> Number of values that have not converged: 5
# 2023-05-16 14:41:57,021 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:41:57,021 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:41:57,021 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:41:57,021 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:41:57,021 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9995644300965083
# ---------> Number of values that have not converged: 14
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9997891518852
# ---------> Number of values that have not converged: 2
# 2023-05-16 14:46:19,052 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:46:19,052 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:46:19,052 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:46:19,052 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:46:19,052 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:46:19,057 - 53 - INFO - ====> Iteration 3 =====
# 2023-05-16 14:46:19,057 - 53 - INFO - ====> Iteration 3 =====
# 2023-05-16 14:46:19,057 - 53 - INFO - ====> Iteration 3 =====
# 2023-05-16 14:46:19,057 - 53 - INFO - ====> Iteration 3 =====
# 2023-05-16 14:46:19,057 - 53 - INFO - ====> Iteration 3 =====
# 2023-05-16 14:46:19,147 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:46:19,147 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:46:19,147 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:46:19,147 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:46:19,147 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:46:19,357 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:46:19,357 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:46:19,357 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:46:19,357 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:46:19,357 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9996137788697331
# ---------> Number of values that have not converged: 56
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0000541326987549
# ---------> Number of values that have not converged: 18
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0002053312426462
# ---------> Number of values that have not converged: 8
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9997867380951512
# ---------> Number of values that have not converged: 1
# 2023-05-16 14:53:11,128 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:53:11,128 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:53:11,128 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:53:11,128 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 14:53:11,128 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9996341462700888
# ---------> Number of values that have not converged: 42
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9994879216852746
# ---------> Number of values that have not converged: 6
# 2023-05-16 14:57:22,459 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:57:22,459 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:57:22,459 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:57:22,459 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:57:22,459 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 14:57:22,463 - 53 - INFO - ====> Iteration 4 =====
# 2023-05-16 14:57:22,463 - 53 - INFO - ====> Iteration 4 =====
# 2023-05-16 14:57:22,463 - 53 - INFO - ====> Iteration 4 =====
# 2023-05-16 14:57:22,463 - 53 - INFO - ====> Iteration 4 =====
# 2023-05-16 14:57:22,463 - 53 - INFO - ====> Iteration 4 =====
# 2023-05-16 14:57:22,560 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:57:22,560 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:57:22,560 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:57:22,560 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:57:22,560 - 64 - INFO - ---------> Random done.
# 2023-05-16 14:57:22,756 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:57:22,756 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:57:22,756 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:57:22,756 - 70 - INFO - ---------> LOO done.
# 2023-05-16 14:57:22,756 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9993036642565316
# ---------> Number of values that have not converged: 75
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9998027313819956
# ---------> Number of values that have not converged: 22
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.000053813514052
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9997870386316581
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9995738150591356
# ---------> Number of values that have not converged: 1
# 2023-05-16 15:04:50,735 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:04:50,735 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:04:50,735 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:04:50,735 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:04:50,735 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0010702145150754
# ---------> Number of values that have not converged: 42
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.000086026692853
# ---------> Number of values that have not converged: 2
# 2023-05-16 15:08:44,692 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:08:44,692 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:08:44,692 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:08:44,692 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:08:44,692 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:08:44,698 - 53 - INFO - ====> Iteration 5 =====
# 2023-05-16 15:08:44,698 - 53 - INFO - ====> Iteration 5 =====
# 2023-05-16 15:08:44,698 - 53 - INFO - ====> Iteration 5 =====
# 2023-05-16 15:08:44,698 - 53 - INFO - ====> Iteration 5 =====
# 2023-05-16 15:08:44,698 - 53 - INFO - ====> Iteration 5 =====
# 2023-05-16 15:08:44,800 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:08:44,800 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:08:44,800 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:08:44,800 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:08:44,800 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:08:45,003 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:08:45,003 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:08:45,003 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:08:45,003 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:08:45,003 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9991798757495917
# ---------> Number of values that have not converged: 59
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9999301613278866
# ---------> Number of values that have not converged: 18
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0003792085887853
# ---------> Number of values that have not converged: 9
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9998476078841609
# ---------> Number of values that have not converged: 2
# 2023-05-16 15:15:32,739 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:15:32,739 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:15:32,739 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:15:32,739 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:15:32,739 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9994911860652403
# ---------> Number of values that have not converged: 53
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9997055003481887
# ---------> Number of values that have not converged: 18
# 2023-05-16 15:19:27,378 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:19:27,378 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:19:27,378 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:19:27,378 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:19:27,378 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:19:27,383 - 53 - INFO - ====> Iteration 6 =====
# 2023-05-16 15:19:27,383 - 53 - INFO - ====> Iteration 6 =====
# 2023-05-16 15:19:27,383 - 53 - INFO - ====> Iteration 6 =====
# 2023-05-16 15:19:27,383 - 53 - INFO - ====> Iteration 6 =====
# 2023-05-16 15:19:27,383 - 53 - INFO - ====> Iteration 6 =====
# 2023-05-16 15:19:27,468 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:19:27,468 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:19:27,468 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:19:27,468 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:19:27,468 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:19:27,677 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:19:27,677 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:19:27,677 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:19:27,677 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:19:27,677 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0011900263405686
# ---------> Number of values that have not converged: 52
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9998305734478597
# ---------> Number of values that have not converged: 20
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9999764147770679
# ---------> Number of values that have not converged: 7
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.000017221860326
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9999106860982603
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0000471896067256
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 3500 - Average convergence rate = 1.0000900626106002
# ---------> Number of values that have not converged: 1
# 2023-05-16 15:30:56,666 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:30:56,666 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:30:56,666 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:30:56,666 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:30:56,666 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0006544107296884
# ---------> Number of values that have not converged: 22
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9999209123974494
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.000582787130873
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9996538535922873
# ---------> Number of values that have not converged: 1
# 2023-05-16 15:38:02,306 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:38:02,306 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:38:02,306 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:38:02,306 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:38:02,306 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:38:02,310 - 53 - INFO - ====> Iteration 7 =====
# 2023-05-16 15:38:02,310 - 53 - INFO - ====> Iteration 7 =====
# 2023-05-16 15:38:02,310 - 53 - INFO - ====> Iteration 7 =====
# 2023-05-16 15:38:02,310 - 53 - INFO - ====> Iteration 7 =====
# 2023-05-16 15:38:02,310 - 53 - INFO - ====> Iteration 7 =====
# 2023-05-16 15:38:02,427 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:38:02,427 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:38:02,427 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:38:02,427 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:38:02,427 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:38:02,621 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:38:02,621 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:38:02,621 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:38:02,621 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:38:02,621 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9997392075479173
# ---------> Number of values that have not converged: 57
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9995682083820857
# ---------> Number of values that have not converged: 16
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9998910550413589
# ---------> Number of values that have not converged: 7
# 2023-05-16 15:43:51,971 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:43:51,971 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:43:51,971 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:43:51,971 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:43:51,971 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9991650187731789
# ---------> Number of values that have not converged: 16
# 2023-05-16 15:46:59,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:46:59,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:46:59,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:46:59,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:46:59,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 15:46:59,485 - 53 - INFO - ====> Iteration 8 =====
# 2023-05-16 15:46:59,485 - 53 - INFO - ====> Iteration 8 =====
# 2023-05-16 15:46:59,485 - 53 - INFO - ====> Iteration 8 =====
# 2023-05-16 15:46:59,485 - 53 - INFO - ====> Iteration 8 =====
# 2023-05-16 15:46:59,485 - 53 - INFO - ====> Iteration 8 =====
# 2023-05-16 15:46:59,563 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:46:59,563 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:46:59,563 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:46:59,563 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:46:59,563 - 64 - INFO - ---------> Random done.
# 2023-05-16 15:46:59,758 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:46:59,758 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:46:59,758 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:46:59,758 - 70 - INFO - ---------> LOO done.
# 2023-05-16 15:46:59,758 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0010914095365675
# ---------> Number of values that have not converged: 55
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0001794918422708
# ---------> Number of values that have not converged: 23
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0001644136775223
# ---------> Number of values that have not converged: 13
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9998645130543315
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9998347009177276
# ---------> Number of values that have not converged: 1
# 2023-05-16 15:54:24,583 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:54:24,583 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:54:24,583 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:54:24,583 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 15:54:24,583 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0012362421893675
# ---------> Number of values that have not converged: 49
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0015101571622487
# ---------> Number of values that have not converged: 23
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0004670830877653
# ---------> Number of values that have not converged: 11
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0009514794522965
# ---------> Number of values that have not converged: 8
# 2023-05-16 16:02:10,095 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:02:10,095 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:02:10,095 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:02:10,095 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:02:10,095 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:02:10,100 - 53 - INFO - ====> Iteration 9 =====
# 2023-05-16 16:02:10,100 - 53 - INFO - ====> Iteration 9 =====
# 2023-05-16 16:02:10,100 - 53 - INFO - ====> Iteration 9 =====
# 2023-05-16 16:02:10,100 - 53 - INFO - ====> Iteration 9 =====
# 2023-05-16 16:02:10,100 - 53 - INFO - ====> Iteration 9 =====
# 2023-05-16 16:02:10,207 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:02:10,207 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:02:10,207 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:02:10,207 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:02:10,207 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:02:10,405 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:02:10,405 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:02:10,405 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:02:10,405 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:02:10,405 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9998991814323606
# ---------> Number of values that have not converged: 53
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9991834430613034
# ---------> Number of values that have not converged: 18
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9995819276046299
# ---------> Number of values that have not converged: 7
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9997067093645008
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9995811383008596
# ---------> Number of values that have not converged: 1
# 2023-05-16 16:09:29,671 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:09:29,671 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:09:29,671 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:09:29,671 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:09:29,671 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0001109763783562
# ---------> Number of values that have not converged: 41
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9993886992124138
# ---------> Number of values that have not converged: 11
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0002075524995055
# ---------> Number of values that have not converged: 5
# 2023-05-16 16:14:52,582 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:14:52,582 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:14:52,582 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:14:52,582 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:14:52,582 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:14:52,587 - 53 - INFO - ====> Iteration 10 =====
# 2023-05-16 16:14:52,587 - 53 - INFO - ====> Iteration 10 =====
# 2023-05-16 16:14:52,587 - 53 - INFO - ====> Iteration 10 =====
# 2023-05-16 16:14:52,587 - 53 - INFO - ====> Iteration 10 =====
# 2023-05-16 16:14:52,587 - 53 - INFO - ====> Iteration 10 =====
# 2023-05-16 16:14:52,696 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:14:52,696 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:14:52,696 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:14:52,696 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:14:52,696 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:14:52,891 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:14:52,891 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:14:52,891 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:14:52,891 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:14:52,891 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.999703135843713
# ---------> Number of values that have not converged: 62
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9996418640393219
# ---------> Number of values that have not converged: 21
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0002299832965063
# ---------> Number of values that have not converged: 11
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.000132950503223
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9999901999378751
# ---------> Number of values that have not converged: 3
# 2023-05-16 16:22:35,747 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:22:35,747 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:22:35,747 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:22:35,747 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:22:35,747 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9987210735926635
# ---------> Number of values that have not converged: 35
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0013441319136644
# ---------> Number of values that have not converged: 15
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.000860957464856
# ---------> Number of values that have not converged: 3
# 2023-05-16 16:28:01,747 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:28:01,747 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:28:01,747 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:28:01,747 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:28:01,747 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:28:01,750 - 53 - INFO - ====> Iteration 11 =====
# 2023-05-16 16:28:01,750 - 53 - INFO - ====> Iteration 11 =====
# 2023-05-16 16:28:01,750 - 53 - INFO - ====> Iteration 11 =====
# 2023-05-16 16:28:01,750 - 53 - INFO - ====> Iteration 11 =====
# 2023-05-16 16:28:01,750 - 53 - INFO - ====> Iteration 11 =====
# 2023-05-16 16:28:01,837 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:28:01,837 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:28:01,837 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:28:01,837 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:28:01,837 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:28:02,030 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:28:02,030 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:28:02,030 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:28:02,030 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:28:02,030 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9996706156958125
# ---------> Number of values that have not converged: 47
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9997931918219911
# ---------> Number of values that have not converged: 25
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9995496743376528
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999153757155002
# ---------> Number of values that have not converged: 2
# 2023-05-16 16:34:02,077 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:34:02,077 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:34:02,077 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:34:02,077 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:34:02,077 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.000118927807521
# ---------> Number of values that have not converged: 56
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9999641092594187
# ---------> Number of values that have not converged: 23
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.000168284194373
# ---------> Number of values that have not converged: 4
# 2023-05-16 16:39:29,433 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:39:29,433 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:39:29,433 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:39:29,433 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:39:29,433 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:39:29,438 - 53 - INFO - ====> Iteration 12 =====
# 2023-05-16 16:39:29,438 - 53 - INFO - ====> Iteration 12 =====
# 2023-05-16 16:39:29,438 - 53 - INFO - ====> Iteration 12 =====
# 2023-05-16 16:39:29,438 - 53 - INFO - ====> Iteration 12 =====
# 2023-05-16 16:39:29,438 - 53 - INFO - ====> Iteration 12 =====
# 2023-05-16 16:39:29,531 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:39:29,531 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:39:29,531 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:39:29,531 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:39:29,531 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:39:29,724 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:39:29,724 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:39:29,724 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:39:29,724 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:39:29,724 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0006441849348093
# ---------> Number of values that have not converged: 54
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0000821827326443
# ---------> Number of values that have not converged: 23
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.999780708340056
# ---------> Number of values that have not converged: 7
# 2023-05-16 16:45:12,138 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:45:12,138 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:45:12,138 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:45:12,138 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:45:12,138 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9994574598903153
# ---------> Number of values that have not converged: 9
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0004507906669897
# ---------> Number of values that have not converged: 5
# 2023-05-16 16:49:48,196 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:49:48,196 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:49:48,196 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:49:48,196 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:49:48,196 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 16:49:48,200 - 53 - INFO - ====> Iteration 13 =====
# 2023-05-16 16:49:48,200 - 53 - INFO - ====> Iteration 13 =====
# 2023-05-16 16:49:48,200 - 53 - INFO - ====> Iteration 13 =====
# 2023-05-16 16:49:48,200 - 53 - INFO - ====> Iteration 13 =====
# 2023-05-16 16:49:48,200 - 53 - INFO - ====> Iteration 13 =====
# 2023-05-16 16:49:48,280 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:49:48,280 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:49:48,280 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:49:48,280 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:49:48,280 - 64 - INFO - ---------> Random done.
# 2023-05-16 16:49:48,476 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:49:48,476 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:49:48,476 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:49:48,476 - 70 - INFO - ---------> LOO done.
# 2023-05-16 16:49:48,476 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0003390957296674
# ---------> Number of values that have not converged: 57
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0001683236056698
# ---------> Number of values that have not converged: 28
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9999911418102942
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0000267311406117
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.00006798016108
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.000082482096539
# ---------> Number of values that have not converged: 1
# 2023-05-16 16:58:59,841 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:58:59,841 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:58:59,841 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:58:59,841 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 16:58:59,841 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.999142173848411
# ---------> Number of values that have not converged: 21
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9994929180904254
# ---------> Number of values that have not converged: 7
# 2023-05-16 17:03:44,848 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:03:44,848 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:03:44,848 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:03:44,848 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:03:44,848 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:03:44,853 - 53 - INFO - ====> Iteration 14 =====
# 2023-05-16 17:03:44,853 - 53 - INFO - ====> Iteration 14 =====
# 2023-05-16 17:03:44,853 - 53 - INFO - ====> Iteration 14 =====
# 2023-05-16 17:03:44,853 - 53 - INFO - ====> Iteration 14 =====
# 2023-05-16 17:03:44,853 - 53 - INFO - ====> Iteration 14 =====
# 2023-05-16 17:03:44,989 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:03:44,989 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:03:44,989 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:03:44,989 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:03:44,989 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:03:45,190 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:03:45,190 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:03:45,190 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:03:45,190 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:03:45,190 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9992424076135541
# ---------> Number of values that have not converged: 58
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0002518116254635
# ---------> Number of values that have not converged: 34
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0003170279376707
# ---------> Number of values that have not converged: 10
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0003278280627361
# ---------> Number of values that have not converged: 8
# 2023-05-16 17:10:44,840 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:10:44,840 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:10:44,840 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:10:44,840 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:10:44,840 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0002894790642574
# ---------> Number of values that have not converged: 49
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9999678712234743
# ---------> Number of values that have not converged: 9
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9998404528797508
# ---------> Number of values that have not converged: 13
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.999777598657432
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.0004889410449942
# ---------> Number of values that have not converged: 1
# 2023-05-16 17:20:43,053 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:20:43,053 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:20:43,053 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:20:43,053 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:20:43,053 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:20:43,057 - 53 - INFO - ====> Iteration 15 =====
# 2023-05-16 17:20:43,057 - 53 - INFO - ====> Iteration 15 =====
# 2023-05-16 17:20:43,057 - 53 - INFO - ====> Iteration 15 =====
# 2023-05-16 17:20:43,057 - 53 - INFO - ====> Iteration 15 =====
# 2023-05-16 17:20:43,057 - 53 - INFO - ====> Iteration 15 =====
# 2023-05-16 17:20:43,176 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:20:43,176 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:20:43,176 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:20:43,176 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:20:43,176 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:20:43,387 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:20:43,387 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:20:43,387 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:20:43,387 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:20:43,387 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0012561884652644
# ---------> Number of values that have not converged: 64
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0000252925951771
# ---------> Number of values that have not converged: 21
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0000480423475933
# ---------> Number of values that have not converged: 6
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0002669373393405
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 2500 - Average convergence rate = 1.00034073585415
# ---------> Number of values that have not converged: 1
# ====> Monte-Carlo Round 3000 - Average convergence rate = 1.0001260727771317
# ---------> Number of values that have not converged: 2
# 2023-05-16 17:30:37,952 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:30:37,952 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:30:37,952 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:30:37,952 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:30:37,952 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9976708005282375
# ---------> Number of values that have not converged: 56
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9978493298321286
# ---------> Number of values that have not converged: 17
# 2023-05-16 17:34:51,057 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:34:51,057 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:34:51,057 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:34:51,057 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:34:51,057 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:34:51,061 - 53 - INFO - ====> Iteration 16 =====
# 2023-05-16 17:34:51,061 - 53 - INFO - ====> Iteration 16 =====
# 2023-05-16 17:34:51,061 - 53 - INFO - ====> Iteration 16 =====
# 2023-05-16 17:34:51,061 - 53 - INFO - ====> Iteration 16 =====
# 2023-05-16 17:34:51,061 - 53 - INFO - ====> Iteration 16 =====
# 2023-05-16 17:34:51,173 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:34:51,173 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:34:51,173 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:34:51,173 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:34:51,173 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:34:51,383 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:34:51,383 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:34:51,383 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:34:51,383 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:34:51,383 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9990752641293531
# ---------> Number of values that have not converged: 54
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9993354010330908
# ---------> Number of values that have not converged: 19
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0002318825474015
# ---------> Number of values that have not converged: 10
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.0000867284544874
# ---------> Number of values that have not converged: 3
# 2023-05-16 17:41:41,324 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:41:41,324 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:41:41,324 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:41:41,324 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 17:41:41,324 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0007215833409246
# ---------> Number of values that have not converged: 12
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9998856230182153
# ---------> Number of values that have not converged: 8
# 2023-05-16 17:46:39,717 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:46:39,717 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:46:39,717 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:46:39,717 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:46:39,717 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 17:46:39,723 - 53 - INFO - ====> Iteration 17 =====
# 2023-05-16 17:46:39,723 - 53 - INFO - ====> Iteration 17 =====
# 2023-05-16 17:46:39,723 - 53 - INFO - ====> Iteration 17 =====
# 2023-05-16 17:46:39,723 - 53 - INFO - ====> Iteration 17 =====
# 2023-05-16 17:46:39,723 - 53 - INFO - ====> Iteration 17 =====
# 2023-05-16 17:46:39,816 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:46:39,816 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:46:39,816 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:46:39,816 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:46:39,816 - 64 - INFO - ---------> Random done.
# 2023-05-16 17:46:40,036 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:46:40,036 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:46:40,036 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:46:40,036 - 70 - INFO - ---------> LOO done.
# 2023-05-16 17:46:40,036 - 70 - INFO - ---------> LOO done.
# ...
# 2023-05-16 17:54:18,870 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.001253262883729
# ---------> Number of values that have not converged: 42
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9994680907944943
# ---------> Number of values that have not converged: 14
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9996714880381051
# ---------> Number of values that have not converged: 1
# 2023-05-16 18:01:03,087 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:01:03,087 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:01:03,087 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:01:03,087 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:01:03,087 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:01:03,091 - 53 - INFO - ====> Iteration 18 =====
# 2023-05-16 18:01:03,091 - 53 - INFO - ====> Iteration 18 =====
# 2023-05-16 18:01:03,091 - 53 - INFO - ====> Iteration 18 =====
# 2023-05-16 18:01:03,091 - 53 - INFO - ====> Iteration 18 =====
# 2023-05-16 18:01:03,091 - 53 - INFO - ====> Iteration 18 =====
# 2023-05-16 18:01:03,187 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:01:03,187 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:01:03,187 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:01:03,187 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:01:03,187 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:01:03,385 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:01:03,385 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:01:03,385 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:01:03,385 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:01:03,385 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0003468158986095
# ---------> Number of values that have not converged: 58
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0002496676689112
# ---------> Number of values that have not converged: 21
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9999843120960553
# ---------> Number of values that have not converged: 8
# ====> Monte-Carlo Round 2000 - Average convergence rate = 1.00033411407372
# ---------> Number of values that have not converged: 8
# 2023-05-16 18:08:22,388 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:08:22,388 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:08:22,388 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:08:22,388 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:08:22,388 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0003094712636236
# ---------> Number of values that have not converged: 44
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9991048135816449
# ---------> Number of values that have not converged: 17
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.999438652442874
# ---------> Number of values that have not converged: 2
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999071703154478
# ---------> Number of values that have not converged: 1
# 2023-05-16 18:15:22,526 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:15:22,526 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:15:22,526 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:15:22,526 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:15:22,526 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:15:22,531 - 53 - INFO - ====> Iteration 19 =====
# 2023-05-16 18:15:22,531 - 53 - INFO - ====> Iteration 19 =====
# 2023-05-16 18:15:22,531 - 53 - INFO - ====> Iteration 19 =====
# 2023-05-16 18:15:22,531 - 53 - INFO - ====> Iteration 19 =====
# 2023-05-16 18:15:22,531 - 53 - INFO - ====> Iteration 19 =====
# 2023-05-16 18:15:22,643 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:15:22,643 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:15:22,643 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:15:22,643 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:15:22,643 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:15:22,837 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:15:22,837 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:15:22,837 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:15:22,837 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:15:22,837 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.999832646376803
# ---------> Number of values that have not converged: 61
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0005119780781755
# ---------> Number of values that have not converged: 24
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9998304991473412
# ---------> Number of values that have not converged: 9
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999968012781524
# ---------> Number of values that have not converged: 4
# 2023-05-16 18:21:52,272 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:21:52,272 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:21:52,272 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:21:52,272 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:21:52,272 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.001392932315685
# ---------> Number of values that have not converged: 48
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0009379546370003
# ---------> Number of values that have not converged: 29
# ====> Monte-Carlo Round 1500 - Average convergence rate = 1.0004130723711713
# ---------> Number of values that have not converged: 8
# 2023-05-16 18:27:17,443 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:27:17,443 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:27:17,443 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:27:17,443 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:27:17,443 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:27:17,448 - 53 - INFO - ====> Iteration 20 =====
# 2023-05-16 18:27:17,448 - 53 - INFO - ====> Iteration 20 =====
# 2023-05-16 18:27:17,448 - 53 - INFO - ====> Iteration 20 =====
# 2023-05-16 18:27:17,448 - 53 - INFO - ====> Iteration 20 =====
# 2023-05-16 18:27:17,448 - 53 - INFO - ====> Iteration 20 =====
# 2023-05-16 18:27:17,545 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:27:17,545 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:27:17,545 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:27:17,545 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:27:17,545 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:27:17,743 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:27:17,743 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:27:17,743 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:27:17,743 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:27:17,743 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.999436159393041
# ---------> Number of values that have not converged: 57
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9996119021854016
# ---------> Number of values that have not converged: 28
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9998939153976562
# ---------> Number of values that have not converged: 7
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.999788531878607
# ---------> Number of values that have not converged: 2
# 2023-05-16 18:33:49,786 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:33:49,786 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:33:49,786 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:33:49,786 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:33:49,786 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9989854810735078
# ---------> Number of values that have not converged: 9
# 2023-05-16 18:36:56,731 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:36:56,731 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:36:56,731 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:36:56,731 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:36:56,731 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:36:56,734 - 53 - INFO - ====> Iteration 21 =====
# 2023-05-16 18:36:56,734 - 53 - INFO - ====> Iteration 21 =====
# 2023-05-16 18:36:56,734 - 53 - INFO - ====> Iteration 21 =====
# 2023-05-16 18:36:56,734 - 53 - INFO - ====> Iteration 21 =====
# 2023-05-16 18:36:56,734 - 53 - INFO - ====> Iteration 21 =====
# 2023-05-16 18:36:56,803 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:36:56,803 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:36:56,803 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:36:56,803 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:36:56,803 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:36:56,999 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:36:56,999 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:36:56,999 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:36:56,999 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:36:56,999 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9982665279452548
# ---------> Number of values that have not converged: 46
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9990502397759635
# ---------> Number of values that have not converged: 23
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9997344873761668
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9999397194401937
# ---------> Number of values that have not converged: 4
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9999708870071311
# ---------> Number of values that have not converged: 1
# 2023-05-16 18:45:09,953 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:45:09,953 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:45:09,953 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:45:09,953 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:45:09,953 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.001704125449615
# ---------> Number of values that have not converged: 62
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9994494088546856
# ---------> Number of values that have not converged: 16
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9992879777884071
# ---------> Number of values that have not converged: 2
# 2023-05-16 18:50:38,446 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:50:38,446 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:50:38,446 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:50:38,446 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:50:38,446 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 18:50:38,451 - 53 - INFO - ====> Iteration 22 =====
# 2023-05-16 18:50:38,451 - 53 - INFO - ====> Iteration 22 =====
# 2023-05-16 18:50:38,451 - 53 - INFO - ====> Iteration 22 =====
# 2023-05-16 18:50:38,451 - 53 - INFO - ====> Iteration 22 =====
# 2023-05-16 18:50:38,451 - 53 - INFO - ====> Iteration 22 =====
# 2023-05-16 18:50:38,565 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:50:38,565 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:50:38,565 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:50:38,565 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:50:38,565 - 64 - INFO - ---------> Random done.
# 2023-05-16 18:50:38,767 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:50:38,767 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:50:38,767 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:50:38,767 - 70 - INFO - ---------> LOO done.
# 2023-05-16 18:50:38,767 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9993211025165942
# ---------> Number of values that have not converged: 60
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.9998963130529265
# ---------> Number of values that have not converged: 24
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9997861021028615
# ---------> Number of values that have not converged: 8
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9998698235899433
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2500 - Average convergence rate = 0.9998952481087494
# ---------> Number of values that have not converged: 1
# 2023-05-16 18:58:09,770 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:58:09,770 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:58:09,770 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:58:09,770 - 77 - INFO - ---------> Shapley done.
# 2023-05-16 18:58:09,770 - 77 - INFO - ---------> Shapley done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 0.9977940881148163
# ---------> Number of values that have not converged: 39
# ====> Monte-Carlo Round 1000 - Average convergence rate = 0.999815934092413
# ---------> Number of values that have not converged: 5
# ====> Monte-Carlo Round 1500 - Average convergence rate = 0.9999566794870328
# ---------> Number of values that have not converged: 3
# ====> Monte-Carlo Round 2000 - Average convergence rate = 0.9996860101373715
# ---------> Number of values that have not converged: 1
# 2023-05-16 19:06:03,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 19:06:03,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 19:06:03,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 19:06:03,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 19:06:03,481 - 85 - INFO - ---------> DeRDaVa done.
# 2023-05-16 19:06:03,486 - 53 - INFO - ====> Iteration 23 =====
# 2023-05-16 19:06:03,486 - 53 - INFO - ====> Iteration 23 =====
# 2023-05-16 19:06:03,486 - 53 - INFO - ====> Iteration 23 =====
# 2023-05-16 19:06:03,486 - 53 - INFO - ====> Iteration 23 =====
# 2023-05-16 19:06:03,486 - 53 - INFO - ====> Iteration 23 =====
# 2023-05-16 19:06:03,604 - 64 - INFO - ---------> Random done.
# 2023-05-16 19:06:03,604 - 64 - INFO - ---------> Random done.
# 2023-05-16 19:06:03,604 - 64 - INFO - ---------> Random done.
# 2023-05-16 19:06:03,604 - 64 - INFO - ---------> Random done.
# 2023-05-16 19:06:03,604 - 64 - INFO - ---------> Random done.
# 2023-05-16 19:06:03,810 - 70 - INFO - ---------> LOO done.
# 2023-05-16 19:06:03,810 - 70 - INFO - ---------> LOO done.
# 2023-05-16 19:06:03,810 - 70 - INFO - ---------> LOO done.
# 2023-05-16 19:06:03,810 - 70 - INFO - ---------> LOO done.
# 2023-05-16 19:06:03,810 - 70 - INFO - ---------> LOO done.
# ====> Monte-Carlo Round 0 - Average convergence rate = 0.0
# ---------> Number of values that have not converged: 100
# ====> Monte-Carlo Round 500 - Average convergence rate = 1.0017637834093476
# ---------> Number of values that have not converged: 50
# ====> Monte-Carlo Round 1000 - Average convergence rate = 1.0009165868950363
# ---------> Number of values that have not converged: 28

# %%
print(X.shape, y.shape, X_test.shape, y_test.shape)
# Out:
# (3172, 5) (3172,) (793, 5) (793,)

# %%
from sklearn.dummy import DummyClassifier

def get_point_addition_performances(model, X_train, y_train, X_test, y_test, order):
    performances = []
    for i in range(1, len(order) + 1):
        if i % 50 == 0: print(i)
        X_train_curr = X_train[order[0:i]]
        y_train_curr = y_train[order[0:i]]
        
        performance = 0
        
        for N in range(50):
            indices = np.asarray(np.random.randint(0, 2, i) == 1).nonzero()[0]
            #print(indices)
            X_train_temp = X_train_curr[indices]
            y_train_temp = y_train_curr[indices]
            
            if not len(y_train_temp):
                performance += 0.5
        
            elif np.all(y_train_temp == y_train_temp[0]):
                performance += DummyClassifier(strategy='constant', constant=y_train_temp[0]) \
                                  .fit(X_train_temp, y_train_temp) \
                                  .score(X_test, y_test)
            else:
                performance += model().fit(X_train_temp, y_train_temp).score(X_test, y_test)
            
        performance /= 50
        performances.append(performance)
    
    return performances

# %%
from urdava.model_utility import model_logistic_regression
import numpy as np

random_performances = []
loo_performances = []
shapley_performances = []
derdava_shapley_performances = []

model = model_logistic_regression

for N in range(50):
    print(f"====> Iteration {N} <====")
    random_performance = get_point_addition_performances(model, X, y, X_test, y_test, random_orders[N])
    random_performances.append(random_performance)
    loo_performance = get_point_addition_performances(model, X, y, X_test, y_test, loo_orders[N])
    loo_performances.append(loo_performance)
    shapley_performance = get_point_addition_performances(model, X, y, X_test, y_test, shapley_orders[N])
    shapley_performances.append(shapley_performance)
    derdava_shapley_performance = get_point_addition_performances(model, X, y, X_test, y_test, derdava_shapley_orders[N])
    derdava_shapley_performances.append(derdava_shapley_performance)
# Out:
# ====> Iteration 0 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 1 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 2 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 3 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 4 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 5 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 6 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 7 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 8 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 9 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 10 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 11 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 12 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 13 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 14 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 15 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 16 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 17 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 18 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 19 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 20 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 21 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 22 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 23 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 24 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 25 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 26 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 27 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 28 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 29 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 30 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 31 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 32 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 33 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 34 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 35 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 36 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 37 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 38 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 39 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 40 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 41 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 42 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 43 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 44 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 45 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 46 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 47 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 48 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 49 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100

# %%
from statistics import mean, stdev

NUM_OF_DATA_SOURCES = 100
support_set = tuple(range(NUM_OF_DATA_SOURCES))

random_performances = np.array(random_performances)
random_means = np.zeros(NUM_OF_DATA_SOURCES + 1)
random_stdevs = np.zeros(NUM_OF_DATA_SOURCES + 1)
loo_performances = np.array(loo_performances)
loo_means = np.zeros(NUM_OF_DATA_SOURCES + 1)
loo_stdevs = np.zeros(NUM_OF_DATA_SOURCES + 1)
shapley_performances = np.array(shapley_performances)
shapley_means = np.zeros(NUM_OF_DATA_SOURCES + 1)
shapley_stdevs = np.zeros(NUM_OF_DATA_SOURCES + 1)
derdava_shapley_performances = np.array(derdava_shapley_performances)
derdava_shapley_means = np.zeros(NUM_OF_DATA_SOURCES + 1)
derdava_shapley_stdevs = np.zeros(NUM_OF_DATA_SOURCES + 1)

for i in support_set:
    random_means[i + 1] = mean(random_performances[:, i])
    random_stdevs[i + 1] = stdev(random_performances[:, i])
    loo_means[i + 1] = mean(loo_performances[:, i])
    loo_stdevs[i + 1] = stdev(loo_performances[:, i])
    shapley_means[i + 1] = mean(shapley_performances[:, i])
    shapley_stdevs[i + 1] = stdev(shapley_performances[:, i])
    derdava_shapley_means[i + 1] = mean(derdava_shapley_performances[:, i])
    derdava_shapley_stdevs[i + 1] = stdev(derdava_shapley_performances[:, i])

# %%
random_means[0] = 0.50
loo_means[0] = 0.50
shapley_means[0] = 0.50
derdava_shapley_means[0] = 0.50

# %%
import matplotlib.pyplot as plt
import os

fig, ax = plt.subplots()
x = np.arange(51)

random_line, = ax.plot(x, random_means[0:51], color="gray")
random_line.set_label("Random")
ax.fill_between(x, (random_means-1/2 * random_stdevs)[0:51], (random_means+1/2 * random_stdevs)[0:51], facecolor="gray", alpha=0.2)

loo_line, = ax.plot(x, loo_means[0:51], color="C1")
loo_line.set_label("LOO")
ax.fill_between(x, (loo_means-1/2 * loo_stdevs)[0:51], (loo_means+1/2 * loo_stdevs)[0:51], facecolor="C1", alpha=0.2)

shapley_line, = ax.plot(x, shapley_means[0:51], color="C0")
shapley_line.set_label("Shapley")
ax.fill_between(x, (shapley_means-1/2 * shapley_stdevs)[0:51], (shapley_means+1/2 * shapley_stdevs)[0:51], facecolor="C0", alpha=0.2)

derdava_shapley_line, = ax.plot(x, derdava_shapley_means[0:51], color="red")
derdava_shapley_line.set_label("DeRDaVa")
ax.fill_between(x, (derdava_shapley_means-1/2 * derdava_shapley_stdevs)[0:51], (derdava_shapley_means+1/2 * derdava_shapley_stdevs)[0:51], facecolor="red", alpha=0.2)

ax.set_xlabel("Number of data added", fontsize=30)
ax.set_ylabel("Expected Accuracy", fontsize=30)
ax.tick_params(axis='both', labelsize='xx-large')

ax.legend(fontsize='xx-large')

plt.show()
PATH_TO_IMAGES = "./images/point_addition_removal/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "par_add_highest"), dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = np.arange(51, 101)

random_line, = ax.plot(100-x, random_means[51:101], color="gray")
random_line.set_label("Random")
ax.fill_between(100-x, (random_means-1/2 * random_stdevs)[51:101], (random_means+1/2 * random_stdevs)[51:101], facecolor="gray", alpha=0.2)

loo_line, = ax.plot(100-x, loo_means[51:101], color="C1")
loo_line.set_label("LOO")
ax.fill_between(100-x, (loo_means-1/2 * loo_stdevs)[51:101], (loo_means+1/2 * loo_stdevs)[51:101], facecolor="C1", alpha=0.2)

shapley_line, = ax.plot(100-x, shapley_means[51:101], color="C0")
shapley_line.set_label("Shapley")
ax.fill_between(100-x, (shapley_means-1/2 * shapley_stdevs)[51:101], (shapley_means+1/2 * shapley_stdevs)[51:101], facecolor="C0", alpha=0.2)

derdava_shapley_line, = ax.plot(100-x, derdava_shapley_means[51:101], color="red")
derdava_shapley_line.set_label("DeRDaVa")
ax.fill_between(100-x, (derdava_shapley_means-1/2 * derdava_shapley_stdevs)[51:101], (derdava_shapley_means+1/2 * derdava_shapley_stdevs)[51:101], facecolor="red", alpha=0.2)

ax.set_xlabel("Number of data removed", fontsize=30)
ax.set_ylabel("Expected Accuracy", fontsize=30)
ax.tick_params(axis='both', labelsize='xx-large')

ax.legend(fontsize='xx-large')

plt.show()
PATH_TO_IMAGES = "./images/point_addition_removal/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "par_remove_lowest"), dpi=300, bbox_inches='tight')

# %%
from urdava.model_utility import model_logistic_regression
import numpy as np

random_performances_ = []
loo_performances_ = []
shapley_performances_ = []
derdava_shapley_performances_ = []

model = model_logistic_regression

for N in range(50):
    print(f"====> Iteration {N} <====")
    random_performance_ = get_point_addition_performances(model, X, y, X_test, y_test, random_orders[N][::-1])
    random_performances_.append(random_performance_)
    loo_performance_ = get_point_addition_performances(model, X, y, X_test, y_test, loo_orders[N][::-1])
    loo_performances_.append(loo_performance_)
    shapley_performance_ = get_point_addition_performances(model, X, y, X_test, y_test, shapley_orders[N][::-1])
    shapley_performances_.append(shapley_performance_)
    derdava_shapley_performance_ = get_point_addition_performances(model, X, y, X_test, y_test, derdava_shapley_orders[N][::-1])
    derdava_shapley_performances_.append(derdava_shapley_performance_)
# Out:
# ====> Iteration 0 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 1 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 2 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 3 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 4 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 5 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 6 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 7 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 8 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 9 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 10 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 11 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 12 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 13 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 14 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 15 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 16 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 17 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 18 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 19 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 20 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 21 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 22 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 23 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 24 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 25 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 26 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 27 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 28 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 29 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 30 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 31 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 32 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 33 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 34 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 35 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 36 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 37 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 38 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 39 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 40 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 41 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 42 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 43 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 44 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 45 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 46 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 47 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 48 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100
# ====> Iteration 49 <====
# 50
# 100
# 50
# 100
# 50
# 100
# 50
# 100

# %%
from statistics import mean, stdev

NUM_OF_DATA_SOURCES = 100
support_set = tuple(range(NUM_OF_DATA_SOURCES))

random_performances_ = np.array(random_performances_)
random_means_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
random_stdevs_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
loo_performances_ = np.array(loo_performances_)
loo_means_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
loo_stdevs_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
shapley_performances_ = np.array(shapley_performances_)
shapley_means_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
shapley_stdevs_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
derdava_shapley_performances_ = np.array(derdava_shapley_performances_)
derdava_shapley_means_ = np.zeros(NUM_OF_DATA_SOURCES + 1)
derdava_shapley_stdevs_ = np.zeros(NUM_OF_DATA_SOURCES + 1)

for i in support_set:
    random_means_[i + 1] = mean(random_performances_[:, i])
    random_stdevs_[i + 1] = stdev(random_performances_[:, i])
    loo_means_[i + 1] = mean(loo_performances_[:, i])
    loo_stdevs_[i + 1] = stdev(loo_performances_[:, i])
    shapley_means_[i + 1] = mean(shapley_performances_[:, i])
    shapley_stdevs_[i + 1] = stdev(shapley_performances_[:, i])
    derdava_shapley_means_[i + 1] = mean(derdava_shapley_performances_[:, i])
    derdava_shapley_stdevs_[i + 1] = stdev(derdava_shapley_performances_[:, i])

# %%
random_means_[0] = 0.50
loo_means_[0] = 0.50
shapley_means_[0] = 0.50
derdava_shapley_means_[0] = 0.50

# %%
import matplotlib.pyplot as plt
import os

fig, ax = plt.subplots()
x = np.arange(51)

random_line_, = ax.plot(x, random_means_[0:51], color="gray")
random_line_.set_label("Random")
ax.fill_between(x, (random_means_-1/2 * random_stdevs_)[0:51], (random_means_+1/2 * random_stdevs_)[0:51], facecolor="gray", alpha=0.2)

loo_line_, = ax.plot(x, loo_means_[0:51], color="C1")
loo_line_.set_label("LOO")
ax.fill_between(x, (loo_means_-1/2 * loo_stdevs_)[0:51], (loo_means_+1/2 * loo_stdevs_)[0:51], facecolor="C1", alpha=0.2)

shapley_line_, = ax.plot(x, shapley_means_[0:51], color="C0")
shapley_line_.set_label("Shapley")
ax.fill_between(x, (shapley_means_-1/2 * shapley_stdevs_)[0:51], (shapley_means_+1/2 * shapley_stdevs_)[0:51], facecolor="C0", alpha=0.2)

derdava_shapley_line_, = ax.plot(x, derdava_shapley_means_[0:51], color="red")
derdava_shapley_line_.set_label("DeRDaVa")
ax.fill_between(x, (derdava_shapley_means_-1/2 * derdava_shapley_stdevs_)[0:51], (derdava_shapley_means_+1/2 * derdava_shapley_stdevs_)[0:51], facecolor="red", alpha=0.2)

ax.set_xlabel("Number of data added", fontsize=30)
ax.set_ylabel("Expected Accuracy", fontsize=30)
ax.tick_params(axis='both', labelsize='xx-large')

#ax.legend(fontsize='xx-large')

plt.show()
PATH_TO_IMAGES = "./images/point_addition_removal/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "par_add_lowest"), dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import os

fig, ax = plt.subplots()
x = np.arange(51, 101)

random_line_, = ax.plot(100-x, random_means_[51:101], color="gray")
random_line_.set_label("Random")
ax.fill_between(100-x, (random_means_-1/2 * random_stdevs_)[51:101], (random_means_+1/2 * random_stdevs_)[51:101], facecolor="gray", alpha=0.2)

loo_line_, = ax.plot(100-x, loo_means_[51:101], color="C1")
loo_line_.set_label("LOO")
ax.fill_between(100-x, (loo_means_-1/2 * loo_stdevs_)[51:101], (loo_means_+1/2 * loo_stdevs_)[51:101], facecolor="C1", alpha=0.2)

shapley_line_, = ax.plot(100-x, shapley_means_[51:101], color="C0")
shapley_line_.set_label("Shapley")
ax.fill_between(100-x, (shapley_means_-1/2 * shapley_stdevs_)[51:101], (shapley_means_+1/2 * shapley_stdevs_)[51:101], facecolor="C0", alpha=0.2)

derdava_shapley_line_, = ax.plot(100-x, derdava_shapley_means_[51:101], color="red")
derdava_shapley_line_.set_label("DeRDaVa")
ax.fill_between(100-x, (derdava_shapley_means_-1/2 * derdava_shapley_stdevs_)[51:101], (derdava_shapley_means_+1/2 * derdava_shapley_stdevs_)[51:101], facecolor="red", alpha=0.2)

ax.set_xlabel("Number of data removed", fontsize=30)
ax.set_ylabel("Expected Accuracy", fontsize=30)
ax.tick_params(axis='both', labelsize='xx-large')

ax.legend(fontsize='xx-large')

plt.show()
PATH_TO_IMAGES = "./images/point_addition_removal/"
if not os.path.isdir(PATH_TO_IMAGES):
    os.makedirs(PATH_TO_IMAGES)
fig.savefig(os.path.join(PATH_TO_IMAGES, "par_remove_highest"), dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import os

fig, ax = plt.subplots()
x = np.arange(101)

random_line_, = ax.plot(x, random_means_, color="gray")
random_line_.set_label("Random")
ax.fill_between(x, (random_means_-1/2 * random_stdevs_), (random_means_+1/2 * random_stdevs_), facecolor="gray", alpha=0.2)

loo_line_, = ax.plot(x, loo_means_, color="C1")
loo_line_.set_label("LOO")
ax.fill_between(x, (loo_means_-1/2 * loo_stdevs_), (loo_means_+1/2 * loo_stdevs_), facecolor="C1", alpha=0.2)

shapley_line_, = ax.plot(x, shapley_means_, color="C0")
shapley_line_.set_label("Shapley")
ax.fill_between(x, (shapley_means_-1/2 * shapley_stdevs_), (shapley_means_+1/2 * shapley_stdevs_), facecolor="C0", alpha=0.2)

derdava_shapley_line_, = ax.plot(x, derdava_shapley_means_, color="red")
derdava_shapley_line_.set_label("DeRDaVa")
ax.fill_between(x, (derdava_shapley_means_-1/2 * derdava_shapley_stdevs_), (derdava_shapley_means_+1/2 * derdava_shapley_stdevs_), facecolor="red", alpha=0.2)

ax.set_xlabel("Number of data added", fontsize=30)
ax.set_ylabel("Expected Accuracy", fontsize=30)
ax.tick_params(axis='both', labelsize='xx-large')

#ax.legend(fontsize='xx-large')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = np.arange(NUM_OF_DATA_SOURCES + 1)

random_line, = ax.plot(x, random_means, color="gray")
random_line.set_label("Random")
ax.fill_between(x, random_means-1/2 * random_stdevs, random_means+1/2 * random_stdevs, facecolor="gray", alpha=0.2)

loo_line, = ax.plot(x, loo_means, color="C1")
loo_line.set_label("LOO")
ax.fill_between(x, loo_means-1/2 * loo_stdevs, loo_means+1/2 * loo_stdevs, facecolor="C1", alpha=0.2)

shapley_line, = ax.plot(x, shapley_means, color="C0")
shapley_line.set_label("Shapley")
ax.fill_between(x, shapley_means-1/2 * shapley_stdevs, shapley_means+1/2 * shapley_stdevs, facecolor="C0", alpha=0.2)

derdava_shapley_line, = ax.plot(x, derdava_shapley_means, color="C3")
derdava_shapley_line.set_label("DeRDaVa Shapley")
ax.fill_between(x, derdava_shapley_means-1/2 * derdava_shapley_stdevs, derdava_shapley_means+1/2 * derdava_shapley_stdevs, facecolor="C3", alpha=0.2)

ax.legend()

plt.show()

# %%
loo_means
# Out:
# array([0.5       , 0.49858772, 0.49888346, 0.50311465, 0.50976031,
#        0.51493512, 0.51973512, 0.52267717, 0.52484472, 0.52845606,
#        0.53379181, 0.53789449, 0.54339654, 0.54522268, 0.55087811,
#        0.54943811, 0.55196787, 0.55418016, 0.5590778 , 0.5609726 ,
#        0.56255685, 0.5651011 , 0.56598803, 0.56953008, 0.57436535,
#        0.57831118, 0.57935181, 0.58366614, 0.5862778 , 0.58781354,
#        0.58874898, 0.59517165, 0.5966652 , 0.60015874, 0.60071055,
#        0.60522205, 0.61044535, 0.6109915 , 0.61184   , 0.6147811 ,
#        0.61692598, 0.62011717, 0.6233222 , 0.62442583, 0.62947339,
#        0.63167874, 0.63347087, 0.6343326 , 0.63642835, 0.63812094,
#        0.64053606, 0.64403402, 0.64354898, 0.64722079, 0.64967433,
#        0.65242268, 0.65264252, 0.65477669, 0.65426772, 0.65640756,
#        0.65783874, 0.65858898, 0.65921953, 0.65992252, 0.66207748,
#        0.66233575, 0.6640485 , 0.66445543, 0.66652535, 0.66676535,
#        0.66669858, 0.66810709, 0.66814992, 0.66971717, 0.67021669,
#        0.67160252, 0.67244283, 0.67304819, 0.67341102, 0.67437858,
#        0.6747074 , 0.67562898, 0.6762022 , 0.67632189, 0.67648441,
#        0.67680252, 0.67688567, 0.67693921, 0.67767937, 0.67693669,
#        0.67748976, 0.67841071, 0.67714961, 0.67801134, 0.67818646,
#        0.67716472, 0.6773915 , 0.67726614, 0.67556472, 0.67362835,
#        0.6718211 ])

# %%
import pickle

obj = [X, X_test, y, y_test]

f = open('train_test_split.pkl', 'wb')
pickle.dump(obj, f)
f.close()

# %%
shapley_stdevs
# Out:
# array([0.        , 0.00759629, 0.00623782, 0.0069027 , 0.00457569,
#        0.00268114, 0.00186693, 0.00148222, 0.00108404, 0.00082959,
#        0.00039105, 0.00102301, 0.00094845, 0.00051967, 0.00187931,
#        0.00193214, 0.00140877, 0.00248302, 0.00288825, 0.00317739,
#        0.00302052, 0.00461974, 0.00455403, 0.00549431, 0.00649447,
#        0.00618009, 0.0068925 , 0.00699904, 0.00733586, 0.00678503,
#        0.00797914, 0.00819714, 0.00824011, 0.00744232, 0.00862844,
#        0.0094943 , 0.00926008, 0.00936359, 0.00929141, 0.00971694,
#        0.01035833, 0.01124271, 0.01085792, 0.01169829, 0.01209722,
#        0.01276622, 0.01362231, 0.01320294, 0.01443648, 0.01440011,
#        0.01394806, 0.01460526, 0.01495582, 0.01505453, 0.01598596,
#        0.01595726, 0.01652533, 0.0162316 , 0.01654624, 0.0166333 ,
#        0.01716107, 0.01750415, 0.01801878, 0.01744311, 0.01778129,
#        0.01726588, 0.01744475, 0.01721741, 0.01733643, 0.01657884,
#        0.01639157, 0.01576617, 0.01519725, 0.0147064 , 0.01468926,
#        0.01401847, 0.01297922, 0.01310605, 0.01333806, 0.0128574 ,
#        0.01217396, 0.01188923, 0.01182705, 0.01217772, 0.01224974,
#        0.01096647, 0.01070795, 0.01037841, 0.00984306, 0.00999224,
#        0.01042427, 0.0113532 , 0.01182493, 0.01129595, 0.01123138,
#        0.01057239, 0.01221085, 0.01271959, 0.01237673, 0.01235059,
#        0.01341933])

# %%
shapley_means-1/2 * shapley_stdevs
# Out:
# array([0.5       , 0.55368483, 0.58422535, 0.59915016, 0.60619261,
#        0.61101252, 0.6137992 , 0.61501803, 0.61559039, 0.61593123,
#        0.61643222, 0.61625899, 0.61623498, 0.61648367, 0.61613576,
#        0.61610379, 0.61633218, 0.61599279, 0.61585676, 0.61571572,
#        0.61586679, 0.61552922, 0.61554795, 0.61556558, 0.61557092,
#        0.61555863, 0.615497  , 0.61559052, 0.61564355, 0.61573434,
#        0.61549946, 0.61546713, 0.61566002, 0.61581932, 0.61566207,
#        0.61573759, 0.61578106, 0.61614191, 0.61602869, 0.61642577,
#        0.61666699, 0.61701673, 0.61778062, 0.61758339, 0.61808001,
#        0.61949331, 0.62071924, 0.62164822, 0.62230509, 0.62364433,
#        0.62443631, 0.62604466, 0.6269806 , 0.62953957, 0.62975431,
#        0.631636  , 0.6333898 , 0.63447134, 0.63602398, 0.63724956,
#        0.63851102, 0.6399082 , 0.64189502, 0.6427932 , 0.64307152,
#        0.64484802, 0.64604383, 0.64714716, 0.64777062, 0.64826039,
#        0.64975478, 0.65099107, 0.65215774, 0.65400821, 0.65463318,
#        0.65589114, 0.65646978, 0.65680233, 0.65715493, 0.6579708 ,
#        0.6586303 , 0.6584796 , 0.65815558, 0.65867835, 0.65819493,
#        0.65877856, 0.65924275, 0.65868419, 0.65836825, 0.65784928,
#        0.65718635, 0.65641873, 0.65519724, 0.65597321, 0.65517725,
#        0.65461444, 0.65217906, 0.6506228 , 0.64983131, 0.64791701,
#        0.64509916])

# %%
shapley_means+1/2 * shapley_stdevs
# Out:
# array([0.5       , 0.56128112, 0.59046317, 0.60605286, 0.6107683 ,
#        0.61369366, 0.61566612, 0.61650025, 0.61667443, 0.61676082,
#        0.61682327, 0.61728199, 0.61718343, 0.61700334, 0.61801506,
#        0.61803593, 0.61774096, 0.61847581, 0.61874501, 0.61889311,
#        0.61888731, 0.62014896, 0.62010198, 0.62105989, 0.62206539,
#        0.62173872, 0.62238951, 0.62258956, 0.6229794 , 0.62251938,
#        0.6234786 , 0.62366427, 0.62390013, 0.62326164, 0.62429051,
#        0.62523189, 0.62504114, 0.6255055 , 0.62532011, 0.62614271,
#        0.62702532, 0.62825944, 0.62863855, 0.62928168, 0.63017724,
#        0.63225953, 0.63434155, 0.63485115, 0.63674157, 0.63804444,
#        0.63838437, 0.64064992, 0.64193642, 0.6445941 , 0.64574027,
#        0.64759326, 0.64991512, 0.65070294, 0.65257022, 0.65388285,
#        0.65567208, 0.65741235, 0.6599138 , 0.66023631, 0.66085281,
#        0.6621139 , 0.66348858, 0.66436457, 0.66510706, 0.66483923,
#        0.66614635, 0.66675723, 0.66735499, 0.66871461, 0.66932244,
#        0.66990961, 0.66944901, 0.66990839, 0.67049299, 0.6708282 ,
#        0.67080426, 0.67036883, 0.66998263, 0.67085607, 0.67044467,
#        0.66974502, 0.66995069, 0.6690626 , 0.66821132, 0.66784152,
#        0.66761062, 0.66777194, 0.66702218, 0.66726916, 0.66640863,
#        0.66518682, 0.66438991, 0.66334239, 0.66220804, 0.6602676 ,
#        0.65851849])
